# %%
# !pip install sentencepiece
# !wget https://raw.githubusercontent.com/google/sentencepiece/master/data/botchan.txt
# !pip install transformers
# !pip install pyvi

# %%
# !git clone https://github.com/rungjoo/CoMPM.git

# %%
# import warnings
# warnings.filterwarnings("ignore")

# %% [markdown]
# # Train

# %%
# !python3 train.py
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Traceback (most recent call last):
#   File "test.py", line 181, in <module>
#     main()
#   File "test.py", line 98, in main
#     dev_dataset = DATA_loader(dev_data_path, model_type)
# NameError: name 'dev_data_path' is not defined

# %% [markdown]
# # Test

# %%
# !python3 test.py
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ###Save Path### Model_Result
#
# Batch Size: 1
# Freeze: no_freeze
# Initial: pretrained
# Model Type: ../PhoBERT/phobert_final
# No model found
# /home/dongnd/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dongnd/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Best Dev F-score: 0.1556
# Dev Accuracy: 0.3
# Test F-score: 0.025
# Test Accuracy: 0.1
